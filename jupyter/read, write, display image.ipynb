# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\mhetr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\mhetr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from opencv-python) (2.2.6)

# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\mhetr\OneDrive\Desktop\OIP (3).webp")

# %%
input
# Out:
# array([[[ 63, 132, 164],
#         [ 63, 132, 164],
#         [ 62, 131, 163],
#         ...,
#         [ 85, 147, 130],
#         [ 84, 149, 131],
#         [ 84, 149, 131]],
#
#        [[ 63, 131, 166],
#         [ 63, 131, 166],
#         [ 62, 130, 165],
#         ...,
#         [ 83, 146, 129],
#         [ 83, 148, 130],
#         [ 83, 148, 130]],
#
#        [[ 63, 131, 167],
#         [ 63, 131, 167],
#         [ 62, 129, 166],
#         ...,
#         [ 81, 144, 127],
#         [ 80, 145, 128],
#         [ 80, 145, 128]],
#
#        ...,
#
#        [[ 80, 209, 197],
#         [ 79, 208, 196],
#         [ 77, 206, 194],
#         ...,
#         [ 70, 162, 111],
#         [ 75, 168, 117],
#         [ 78, 170, 119]],
#
#        [[ 66, 197, 187],
#         [ 78, 209, 199],
#         [ 76, 206, 197],
#         ...,
#         [ 88, 175, 125],
#         [ 83, 171, 120],
#         [ 80, 167, 117]],
#
#        [[ 64, 198, 187],
#         [ 76, 209, 199],
#         [ 74, 207, 197],
#         ...,
#         [ 90, 175, 125],
#         [ 85, 170, 120],
#         [ 82, 167, 117]]], shape=(234, 412, 3), dtype=uint8)

# %%
cv2.imshow("Dog", input)

# %%
cv2.imshow("Dog", input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print('Height of Image:',int(input.shape[0]),'pixels')
print('Width of Image:',int(input.shape[1]),'pixels')
# Out:
# Height of Image: 234 pixels
# Width of Image: 412 pixels

# %%
cv2.imwrite('output.png',input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\mhetr\\POC'
